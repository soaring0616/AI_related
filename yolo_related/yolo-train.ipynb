# %% [markdown]
# ## 模型微調

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8s.pt")  # build a new model from YAML

# Train the model
results = model.train(data=r"my-yolo.yaml", epochs=20, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.52  Python-3.12.2 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
# engine\trainer: task=detect, mode=train, model=yolov8s.pt, data=my-yolo.yaml, epochs=20, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train14, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train14
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# train: Scanning D:\yolo\e_fence\demo_data\demo\project-7-at-2024-07-18-15-13-0ba58273\labels\train... 39 images, 0 backgrounds, 0 corrupt: 100%|██████████| 39/39 [00:00<00:00, 699.97it/s]
# train: New cache created: D:\yolo\e_fence\demo_data\demo\project-7-at-2024-07-18-15-13-0ba58273\labels\train.cache
# val: Scanning D:\yolo\e_fence\demo_data\demo\project-7-at-2024-07-18-15-13-0ba58273\labels\train.cache... 39 images, 0 backgrounds, 0 corrupt: 100%|██████████| 39/39 [00:00<?, ?it/s]
# Plotting labels to runs\detect\train14\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train14
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      4.08G      2.804      8.099      1.879         32        640: 100%|██████████| 3/3 [00:03<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.37it/s]
#                    all         39        110      0.641      0.236      0.242     0.0854
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      4.08G      2.906      7.021      2.057         36        640: 100%|██████████| 3/3 [00:00<00:00,  3.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.82it/s]
#                    all         39        110       0.63      0.236      0.239     0.0848
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      4.11G      2.804      8.251      1.963         30        640: 100%|██████████| 3/3 [00:01<00:00,  2.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.86it/s]
#                    all         39        110      0.314      0.236      0.161     0.0621
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      4.18G      2.078      3.728      1.422         30        640: 100%|██████████| 3/3 [00:01<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.50it/s]
#                    all         39        110      0.818      0.664      0.742      0.372
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      4.02G      1.595      2.175      1.103         26        640: 100%|██████████| 3/3 [00:00<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
#                    all         39        110       0.91      0.641      0.848      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      4.18G      1.265      1.435      1.029         25        640: 100%|██████████| 3/3 [00:00<00:00,  3.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.43it/s]
#                    all         39        110      0.916      0.892      0.932       0.59
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      4.07G      1.365      1.214      1.073         29        640: 100%|██████████| 3/3 [00:00<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
#                    all         39        110      0.967      0.792      0.869      0.545
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      4.03G      1.258      1.137      1.054         31        640: 100%|██████████| 3/3 [00:00<00:00,  3.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
#                    all         39        110        0.7      0.657      0.744      0.483
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      4.07G      1.274     0.9946      1.016         37        640: 100%|██████████| 3/3 [00:00<00:00,  3.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
#                    all         39        110      0.361      0.755        0.5      0.374
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      4.03G      1.224     0.9074      1.012         33        640: 100%|██████████| 3/3 [00:00<00:00,  3.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
#                    all         39        110      0.225        0.8      0.221      0.138
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      4.07G      1.175      1.098     0.9986         15        640: 100%|██████████| 3/3 [00:07<00:00,  2.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.33it/s]
#                    all         39        110      0.115      0.836      0.113     0.0697
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      4.03G       1.12      1.011     0.9683         17        640: 100%|██████████| 3/3 [00:00<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.00it/s]
#                    all         39        110      0.112        0.9       0.11     0.0716
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      4.07G      1.141     0.9889     0.9464         13        640: 100%|██████████| 3/3 [00:00<00:00,  3.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.88it/s]
#                    all         39        110      0.137      0.909      0.135     0.0887
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      4.03G      1.174     0.9301     0.9497          9        640: 100%|██████████| 3/3 [00:00<00:00,  3.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.89it/s]
#                    all         39        110       0.49      0.718      0.621      0.437
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      4.07G      1.022     0.8014     0.9615         15        640: 100%|██████████| 3/3 [00:00<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
#                    all         39        110      0.999      0.909      0.952      0.695
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      4.19G     0.9842     0.7468     0.9064         15        640: 100%|██████████| 3/3 [00:00<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.12it/s]
#                    all         39        110      0.949      0.851      0.927      0.675
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      4.07G      1.136     0.7968      1.015         15        640: 100%|██████████| 3/3 [00:00<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.37it/s]
#                    all         39        110      0.923        0.9      0.934      0.669
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      4.19G      1.084     0.7369     0.9407         20        640: 100%|██████████| 3/3 [00:00<00:00,  3.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.13it/s]
#                    all         39        110      0.998      0.918      0.976      0.703
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      4.19G      1.099     0.7291     0.9197         16        640: 100%|██████████| 3/3 [00:00<00:00,  3.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
#                    all         39        110      0.965      0.955      0.993      0.713
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      4.03G      1.047     0.7068      0.914         17        640: 100%|██████████| 3/3 [00:00<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
#                    all         39        110      0.971      0.991      0.993      0.717
# 20 epochs completed in 0.016 hours.
# Optimizer stripped from runs\detect\train14\weights\last.pt, 22.5MB
# Optimizer stripped from runs\detect\train14\weights\best.pt, 22.5MB
#
# Validating runs\detect\train14\weights\best.pt...
# Ultralytics YOLOv8.2.52  Python-3.12.2 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.79it/s]
#                    all         39        110      0.967      0.991      0.993      0.716
# Speed: 0.1ms preprocess, 5.1ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs\detect\train14

# %% [markdown]
# ## 微調後模型測試

# %%
import os
import numpy as np
import cv2
from ultralytics import YOLO
import torch

# %%
custom_model = YOLO(r"D:\yolo\e_fence\runs\detect\train14\weights\best.pt")  # 抓performance最好的模型
custom_model.to(torch.device("cuda"))
detection_threshold = 0.4

# %%
### --- danger zone plotting --- ###

from AreaEntity import AreaEntity

# Data Loading
import json
with open("demo_data\demo\danger_area_coord.json")as f:
    danger_zone = json.load(f)
    
# danger_zone[2]['annotations'][0]['result'][0]['value']
danger1 = AreaEntity(danger_zone[2]['annotations'][0]['result'][0]['value']['points'])
danger2 = AreaEntity(danger_zone[2]['annotations'][0]['result'][1]['value']['points'])
# Out:
# <>:38: SyntaxWarning: invalid escape sequence '\d'
# <>:38: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\mycena\AppData\Local\Temp\ipykernel_22264\1940567532.py:38: SyntaxWarning: invalid escape sequence '\d'
#   with open("demo_data\demo\danger_area_coord.json")as f:

# %%
video_path = r"demo_data\output.mp4"
cap = cv2.VideoCapture(video_path) # 創建 VideoCapture 物件

# 取得影像的屬性
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS) 


# 寫入影像的設定
fourcc = cv2.VideoWriter_fourcc(*'mp4v')          # 設定影片的格式為 MJPG
out = cv2.VideoWriter('detection_demo_outputa.mp4', fourcc, 15, (frame_width,  frame_height))  # 產生空的影片

cv2.namedWindow('demo', cv2.WINDOW_NORMAL)

danger1_2d = danger1.contour.squeeze()
actual_danger1 = danger1_2d.copy()
actual_danger1[:, 0] = (danger1_2d[:, 0] / 100.0) * frame_width
actual_danger1[:, 1] = (danger1_2d[:, 1] / 100.0) * frame_height

danger2_2d = danger2.contour.squeeze()
actual_danger2 = danger2_2d.copy()
actual_danger2[:, 0] = (danger2_2d[:, 0] / 100.0) * frame_width
actual_danger2[:, 1] = (danger2_2d[:, 1] / 100.0) * frame_height

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = custom_model.predict(frame, conf=detection_threshold, show_labels=True, classes=0, imgsz=1200)        
        
    situation = "Normal"

        
    cv2.polylines(frame, [actual_danger1], True, (0, 255, 0), 3)
    cv2.polylines(frame, [actual_danger2], True, (0, 255, 0), 3)
    
    for item in results[0].boxes.xyxy:
        
        color = (255, 0, 0)
        
        item = item.cpu().numpy()
        cx = int((item[0]+item[2])//2)
        cy = int((item[1]+item[3])//2)
        
        dangerstate_c1 = cv2.pointPolygonTest(actual_danger1, (cx, cy), False)
        dangerstate_c2 = cv2.pointPolygonTest(actual_danger2, (cx, cy), False)

        if dangerstate_c1>0 or dangerstate_c2>0 :
            color =  (0, 0, 255)
            situation = "WARNING!"
 
        # cv2.putText(frame, f'dangerstate_c1:{dangerstate_c1}, dangerstate_c2:{dangerstate_c2}', tuple((0, int(item[1]))), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 4)
        cv2.circle(frame, (cx, cy), 2, color ,0)
        cv2.rectangle(frame, tuple(np.int16(item[:2]).tolist()) , tuple(np.int16(item[-2:]).tolist()), color, 2)

    
    cv2.rectangle(frame, (0,0), (1000,150), (0,0,0), -1) # 標示出異常情況
    info_color =  (0, 0, 255) if situation == 'WARNING!' else  (255, 0, 0)
    cv2.putText(frame, f'Current situation:{situation}', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 2, info_color, 4)


    out.write(frame)
    cv2.imshow('demo', frame)
    # 按下 'q' 鍵退出
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# 釋放所有資源
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 227.0ms
# Speed: 14.0ms preprocess, 227.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 101.0ms
# Speed: 11.0ms preprocess, 101.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 53.0ms
# Speed: 7.0ms preprocess, 53.0ms inference, 7.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 20.0ms
# Speed: 7.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 21.0ms
# Speed: 12.0ms preprocess, 21.0ms inference, 4.1ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 20.0ms
# Speed: 7.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 8.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 20.0ms
# Speed: 14.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 18.5ms
# Speed: 10.4ms preprocess, 18.5ms inference, 5.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 10.0ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 20.0ms
# Speed: 17.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 9.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 6.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 15.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 6.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 19.0ms
# Speed: 8.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 2 persons, 19.0ms
# Speed: 6.0ms preprocess, 19.0ms inference, 6.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 2 persons, 20.0ms
# Speed: 21.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 2 persons, 18.7ms
# Speed: 8.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 2 persons,
0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 32.0ms
# Speed: 6.2ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 32.0ms
# Speed: 7.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 31.0ms
# Speed: 7.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 31.0ms
# Speed: 7.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 32.0ms
# Speed: 7.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 (no detections), 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 18.9ms preprocess, 32.0ms inference, 6.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 31.0ms
# Speed: 6.0ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.3ms
# Speed: 8.0ms preprocess, 32.3ms inference, 2.6ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 31.0ms
# Speed: 7.0ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 35.0ms
# Speed: 17.0ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 34.0ms
# Speed: 16.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 34.1ms
# Speed: 6.0ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 34.0ms
# Speed: 15.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 36.0ms
# Speed: 16.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 36.0ms
# Speed: 5.8ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 35.9ms
# Speed: 6.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 38.0ms
# Speed: 5.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 38.0ms
# Speed: 17.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 8.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 6.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 7.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 38.0ms
# Speed: 19.0ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 6.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 16.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 6.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 6.8ms preprocess, 37.0ms inference, 3.5ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.7ms
# Speed: 19.0ms preprocess, 37.7ms inference, 3.4ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 39.0ms
# Speed: 6.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 39.0ms
# Speed: 6.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 13.0ms preprocess, 37.0ms inference, 3.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 7.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 1216)
#
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
# 0: 704x1216 1 person, 37.0ms
# Speed: 6.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 704, 1216)

# %% [markdown]
# ## 數據擷取

# %%
import os
import numpy as np
import cv2
import torch

cv2.namedWindow('demo')
detection_threshold = 0.
num_frame = 0
num_pic = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    num_frame+=1
    
    if num_frame%10 == 0:
        cv2.imwrite(os.path.join("demo_data", "嘉義 「蘭潭水庫 小公園」 360 4K全景影像", str(num_pic)+"_小公園.jpg"), frame)
        num_pic+=1
    
    cv2.imshow('demo', frame)

    # 按下 'q' 鍵退出
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# 釋放所有資源
cap.release()
cv2.destroyAllWindows()
